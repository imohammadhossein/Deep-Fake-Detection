.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zsHVKcjzTFnX9nCP.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZSNeKYrMA1kD5ZAR.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZStj8A2e5wFVfoef.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZT3zDwZXJQKPuQHe.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZTHcfAzTJk1TGnsm.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZTtCFxNFjdE5v1UV.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zTXT3MmMmrfhT4pE.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ztY8R5E3oSPamsTU.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_Zu7Bt9PHGfoYwOCn.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zUbGXmGczsx4BOph.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zUDV8ckuXDi75TiP.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zuKdYdWZI3ffR16K.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZuNMqbTNCg0ZRVcs.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zusQreFoSQfSSvA8.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zUvGW0qhXi8m97Pd.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZUzTmict6QKjeeOc.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zv7PP5SbPtC4mr4C.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zvGL5GRZNoHVioyd.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zVJQasGGkilszrxz.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zvNof3qUh0znezBY.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zVOOCfFEYRUUUyuH.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZvRN74EHZeqTElqb.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zVvUQlPU99fLl028.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zW0iiKhJZKa8oPZT.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zWJ9ZcTFkFt3J9EU.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZWKiRDJnQEDMclFt.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zwuC7J7O80MliWLM.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZWxfFfA3EqVOrEEj.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zwyw9NhZynEXt9D3.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zxbRZ7funDNJGRlT.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZXbYGRUUQ4SwmNg2.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zXd36GznpnOmtpSE.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZXdbC8uChvf24ovD.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZXeec5HS9OMfxXNM.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZxgORG32UqHPV8Oz.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zXhmVjAsGCDyEA9G.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zxivTLtENHJ4vUJJ.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zXKqHy7mxWHPUuif.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZxNj6Pfk6cijuNB1.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zxOmgtFLEMGPVU23.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zxotRxmBIOjXlN2a.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zXPrGWLba7cm9ozh.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zxQP0yuV9NzEbjaH.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZXSZIlWfnDU04Mr1.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZxUoQnHKZP57FmcP.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZXYK75xIj5vZZQ6n.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zY2jAhujEDuMy4RC.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zYCFFk9RrRLetSbl.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zydskh6fzjHUXGaj.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_Zyhah6ZnQAr4wLVK.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zYId7h8EgmA0gyLz.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zyjdCpTV3Hd12lgL.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zyNYXinCwYrMA60o.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZYYnbs2EHWfBpMV3.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZyZMe6XEigj8Kk38.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zZ8yIUwHVOEtWhrl.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZzAcXmhNmdi8d4D2.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zzDl8dItsFMFsId4.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zzdxcf8M4wdAtY2j.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZzhJDybGCQMYSasf.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZZkF2T7RNwtpfHe1.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_zZsbbkUJS4ss3lhf.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZzweU4v2XuDDQ4kP.jpg
#   inflating: dataset/dfdc/validation/REAL/REAL_ZzwuvrTxyIa9XQkN.jpg

# %%
import os
import numpy as np
# %tensorflow_version 1.x
import tensorflow as tf
from keras.preprocessing import image
from kerasvggface.keras_vggface.vggface import VGGFace
from kerasvggface.keras_vggface import utils
from keras.engine import  Model
from keras.layers import Flatten, Dense, Input
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
import config
from imutils import paths
from keras.layers.core import Dropout
from keras.callbacks import ModelCheckpoint
from keras.optimizers import SGD

# derive the paths to the training, validation, and testing
# directories
trainPath = os.path.sep.join([config.BASE_PATH, config.TRAIN])
valPath = os.path.sep.join([config.BASE_PATH, config.VAL])
testPath = os.path.sep.join([config.BASE_PATH, config.TEST])

# determine the total number of image paths in training, validation,
# and testing directories
totalTrain = len(list(paths.list_images(trainPath)))
totalVal = len(list(paths.list_images(valPath)))
totalTest = len(list(paths.list_images(testPath)))

# initialize the training data augmentation object
trainAug = ImageDataGenerator(
	zoom_range=0.15,
	width_shift_range=0.2,
	height_shift_range=0.2,
	shear_range=0.15,
	horizontal_flip=False,
	fill_mode="nearest")

# initialize the validation/testing data augmentation object (which
# we'll be adding mean subtraction to)
valAug = ImageDataGenerator()

# initialize the training generator
trainGen = trainAug.flow_from_directory(
	trainPath,
	class_mode="categorical",
	target_size=(224, 224),
	color_mode="rgb",
	shuffle=True,
	batch_size=config.BATCH_SIZE)

# initialize the validation generator
valGen = valAug.flow_from_directory(
	valPath,
	class_mode="categorical",
	target_size=(224, 224),
	color_mode="rgb",
	shuffle=False,
	batch_size=config.BATCH_SIZE)

# initialize the testing generator
testGen = valAug.flow_from_directory(
	testPath,
	class_mode="categorical",
	target_size=(224, 224),
	color_mode="rgb",
	shuffle=False,
	batch_size=config.BATCH_SIZE)

labels = (trainGen.class_indices)
print("..." , labels)

def my_gen(gen):
  i = 0
  while True:
    try:
        data, labels = next(gen)
        yield data, labels
    except:
        print(i)
        i += 1
        pass

#custom parameters
nb_class = 2
hidden_dim = 512

resnet_model = VGGFace( model='resnet50' , include_top=False, input_shape=(224, 224, 3))
resnet_model.summary()

print('Len layers: ' , len(resnet_model.layers))

last_layer = resnet_model.get_layer('avg_pool').output
x = Flatten(name='flatten')(last_layer)
x = Dense(hidden_dim, activation='relu', name='fully_connected_1')(x)
x = Dropout(0.5)(x)
out = Dense(nb_class, activation='softmax', name='fully_connected_2')(x)

custom_resnet_model = Model(resnet_model.input, out)

#loop over all layers in the base model and freeze them so they will
# *not* be updated during the first training process
for layer in resnet_model.layers:
	layer.trainable = False

# checkpoint
filepath= "drive/My Drive/VGGFace_ResNet50_headmodel/weights.{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
callbacks_list = [checkpoint]

# compile our model (this needs to be done after our setting our
# layers to being non-trainable
print("[INFO] compiling model...")
opt = SGD(lr=1e-4, momentum=0.9)
custom_resnet_model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])

# train the head of the network for a few epochs (all other layers
# are frozen) -- this will allow the new FC layers to start to become
# initialized with actual "learned" values versus pure random
print("[INFO] training head...")
H = custom_resnet_model.fit_generator(
	my_gen(trainGen),
	steps_per_epoch=totalTrain // config.BATCH_SIZE,
	validation_data=my_gen(valGen),
	validation_steps=totalVal // config.BATCH_SIZE,
	epochs=15 , callbacks = callbacks_list)

# PLOT
history = H
import matplotlib.pyplot as plt
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss'] 
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# Found 149553 images belonging to 2 classes.
# Found 18691 images belonging to 2 classes.
# Found 18705 images belonging to 2 classes.
# ... {'FAKE': 0, 'REAL': 1}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-2c998056529d> in <module>()
#      86 hidden_dim = 512
#      87
# ---> 88 resnet_model = VGGFace( model='resnet50' , include_top=False, input_shape=(224, 224, 3))
#      89 resnet_model.summary()
#      90
#
# /content/kerasvggface/keras_vggface/vggface.py in VGGFace(include_top, model, weights, input_tensor, input_shape, pooling, classes)
#      95                         input_shape=input_shape, pooling=pooling,
#      96                         weights=weights,
# ---> 97                         classes=classes)
#      98
#      99     if model == 'senet50':
#
# /content/kerasvggface/keras_vggface/models.py in RESNET50(include_top, weights, input_tensor, input_shape, pooling, classes)
#     231         64, (7, 7), use_bias=False, strides=(2, 2), padding='same',
#     232         name='conv1/7x7_s2')(img_input)
# --> 233     x = BatchNormalization(axis=bn_axis, name='conv1/7x7_s2/bn')(x)
#     234     x = Activation('relu')(x)
#     235     x = MaxPooling2D((3, 3), strides=(2, 2))(x)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     449             # Actually call the layer,
#     450             # collecting output(s), mask(s), and shape(s).
# --> 451             output = self.call(inputs, **kwargs)
#     452             output_mask = self.compute_mask(inputs, previous_mask)
#     453
#
# /usr/local/lib/python3.6/dist-packages/keras/layers/normalization.py in call(self, inputs, training)
#     183         normed_training, mean, variance = K.normalize_batch_in_training(
#     184             inputs, self.gamma, self.beta, reduction_axes,
# --> 185             epsilon=self.epsilon)
#     186
#     187         if K.backend() != 'cntk':
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in normalize_batch_in_training(x, gamma, beta, reduction_axes, epsilon)
#    2063     """
#    2064     if ndim(x) == 4 and list(reduction_axes) in [[0, 1, 2], [0, 2, 3]]:
# -> 2065         if not _has_nchw_support() and list(reduction_axes) == [0, 2, 3]:
#    2066             return _broadcast_normalize_batch_in_training(x, gamma, beta,
#    2067                                                           reduction_axes,
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _has_nchw_support()
#     310     """
#     311     explicitly_on_cpu = _is_current_explicit_device('CPU')
# --> 312     gpus_available = len(_get_available_gpus()) > 0
#     313     return (not explicitly_on_cpu and gpus_available)
#     314
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _get_available_gpus()
#     294     global _LOCAL_DEVICES
#     295     if _LOCAL_DEVICES is None:
# --> 296         _LOCAL_DEVICES = get_session().list_devices()
#     297     return [x.name for x in _LOCAL_DEVICES if x.device_type == 'GPU']
#     298
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in get_session()
#     221                     v._keras_initialized = True
#     222                 if uninitialized_vars:
# --> 223                     session.run(tf.variables_initializer(uninitialized_vars))
#     224     # hack for list_devices() function.
#     225     # list_devices() function is not available under tensorflow r1.3.
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# !pip install tensorflow==1.14.
# Out:
# Collecting tensorflow==1.14.
#   Downloading https://files.pythonhosted.org/packages/de/f0/96fb2e0412ae9692dbf400e5b04432885f677ad6241c088ccc5fe7724d69/tensorflow-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (109.2MB)
#      |████████████████████████████████| 109.2MB 92kB/s
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.) (1.0.8)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 46.5MB/s
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.) (3.10.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.) (0.8.1)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 50.4MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.) (0.34.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.) (0.9.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.) (0.3.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.) (1.12.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.) (1.12.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.) (1.27.2)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.) (1.18.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14.) (2.10.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.) (3.2.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.) (1.0.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.) (46.0.0)
# Installing collected packages: tensorboard, tensorflow-estimator, tensorflow
#   Found existing installation: tensorboard 2.1.1
#     Uninstalling tensorboard-2.1.1:
#       Successfully uninstalled tensorboard-2.1.1
#   Found existing installation: tensorflow-estimator 2.2.0rc0
#     Uninstalling tensorflow-estimator-2.2.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.2.0rc0
#   Found existing installation: tensorflow 2.2.0rc1
#     Uninstalling tensorflow-2.2.0rc1:
#       Successfully uninstalled tensorflow-2.2.0rc1
# Successfully installed tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0

# %%
import config
from keras.models import load_model
import os
import numpy as np
# %tensorflow_version 1.x
import tensorflow as tf
from keras.preprocessing import image
from kerasvggface.keras_vggface.vggface import VGGFace
from kerasvggface.keras_vggface import utils
from keras.engine import  Model
from keras.layers import Flatten, Dense, Input
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
import config
from imutils import paths
from keras.layers.core import Dropout
from keras.callbacks import ModelCheckpoint
from keras.optimizers import SGD

# derive the paths to the training, validation, and testing
# directories
trainPath = os.path.sep.join([config.BASE_PATH, config.TRAIN])
valPath = os.path.sep.join([config.BASE_PATH, config.VAL])
testPath = os.path.sep.join([config.BASE_PATH, config.TEST])

# determine the total number of image paths in training, validation,
# and testing directories
totalTrain = len(list(paths.list_images(trainPath)))
totalVal = len(list(paths.list_images(valPath)))
totalTest = len(list(paths.list_images(testPath)))

# initialize the training data augmentation object
trainAug = ImageDataGenerator(
	zoom_range=0.15,
	width_shift_range=0.2,
	height_shift_range=0.2,
	shear_range=0.15,
	horizontal_flip=False,
	fill_mode="nearest")

# initialize the validation/testing data augmentation object (which
# we'll be adding mean subtraction to)
valAug = ImageDataGenerator()

# initialize the training generator
trainGen = trainAug.flow_from_directory(
	trainPath,
	class_mode="categorical",
	target_size=(224, 224),
	color_mode="rgb",
	shuffle=True,
	batch_size=config.BATCH_SIZE)

# initialize the validation generator
valGen = valAug.flow_from_directory(
	valPath,
	class_mode="categorical",
	target_size=(224, 224),
	color_mode="rgb",
	shuffle=False,
	batch_size=config.BATCH_SIZE)

# initialize the testing generator
testGen = valAug.flow_from_directory(
	testPath,
	class_mode="categorical",
	target_size=(224, 224),
	color_mode="rgb",
	shuffle=False,
	batch_size=config.BATCH_SIZE)

labels = (trainGen.class_indices)
print("..." , labels)

def my_gen(gen):
  i = 0
  while True:
    try:
        data, labels = next(gen)
        yield data, labels
    except:
        print(i)
        i += 1
        pass

#custom parameters
nb_class = 2
hidden_dim = 512

resnet_model = VGGFace( model='resnet50' , include_top=False, input_shape=(224, 224, 3))
resnet_model.summary()

print('Len layers: ' , len(resnet_model.layers))

last_layer = resnet_model.get_layer('avg_pool').output
x = Flatten(name='flatten')(last_layer)
x = Dense(hidden_dim, activation='relu', name='fully_connected_1')(x)
x = Dropout(0.5)(x)
out = Dense(nb_class, activation='softmax', name='fully_connected_2')(x)

custom_resnet_model = Model(resnet_model.input, out)

# reset the testing generator and evaluate the network after
# fine-tuning just the network head
print("[INFO] evaluating after fine-tuning network head...")
testGen.reset()

# reset our data generators
trainGen.reset()
valGen.reset()

#loop over all layers in the base model and freeze them so they will
# *not* be updated during the first training process
for layer in resnet_model.layers:
	layer.trainable = False

# now that the head FC layers have been trained/initialized, lets
# unfreeze the final set of CONV layers and make them trainable
for layer in resnet_model.layers[0:]:
	layer.trainable = True

# loop over the layers in the model and show which ones are trainable
# or not
for layer in resnet_model.layers:
	print("{}: {}".format(layer, layer.trainable))

custom_resnet_model.load_weights("drive/My Drive/VGGFace_ResNet50_headmodel/weights.15-0.45.hdf5")

# checkpoint
filepath= "drive/My Drive/VGGFace_ResNet50_custommodel/weights.{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
callbacks_list = [checkpoint]

# for the changes to the model to take affect we need to recompile
# the model, this time using SGD with a *very* small learning rate
print("[INFO] re-compiling model...")
# opt = SGD(lr=1e-4, momentum=0.9)
custom_resnet_model.compile(loss="categorical_crossentropy", optimizer=optimizers.Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.001, amsgrad=False),metrics=['accuracy'])

# train the model again, this time fine-tuning *both* the final set
# of CONV layers along with our set of FC layers
H = custom_resnet_model.fit_generator(
	my_gen(trainGen),
	steps_per_epoch=totalTrain // config.BATCH_SIZE,
	validation_data=my_gen(valGen),
	validation_steps=totalVal // config.BATCH_SIZE,
	epochs=15 , callbacks=callbacks_list)

# serialize the model to disk
print("[INFO] serializing network...")
custom_resnet_model.save(config.MODEL_PATH)

# PLOT
history = H
import matplotlib.pyplot as plt
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss'] 
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 60
# Found 149553 images belonging to 2 classes.
# Found 18691 images belonging to 2 classes.
# Found 18705 images belonging to 2 classes.
# ... {'FAKE': 0, 'REAL': 1}
# 0
# Exception ignored in: <generator object my_gen at 0x7fc970fbefc0>
# RuntimeError: generator ignored GeneratorExit
# Exception ignored in: <generator object my_gen at 0x7fc970759360>
# RuntimeError: generator ignored GeneratorExit
# 0
# Model: "vggface_resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1/7x7_s2 (Conv2D)           (None, 112, 112, 64) 9408        input_4[0][0]
# __________________________________________________________________________________________________
# conv1/7x7_s2/bn (BatchNormaliza (None, 112, 112, 64) 256         conv1/7x7_s2[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 112, 112, 64) 0           conv1/7x7_s2/bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 55, 55, 64)   0           activation_99[0][0]
# __________________________________________________________________________________________________
# conv2_1_1x1_reduce (Conv2D)     (None, 55, 55, 64)   4096        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2_1_1x1_reduce/bn (BatchNor (None, 55, 55, 64)   256         conv2_1_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 55, 55, 64)   0           conv2_1_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv2_1_3x3 (Conv2D)            (None, 55, 55, 64)   36864       activation_100[0][0]
# __________________________________________________________________________________________________
# conv2_1_3x3/bn (BatchNormalizat (None, 55, 55, 64)   256         conv2_1_3x3[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 55, 55, 64)   0           conv2_1_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv2_1_1x1_increase (Conv2D)   (None, 55, 55, 256)  16384       activation_101[0][0]
# __________________________________________________________________________________________________
# conv2_1_1x1_proj (Conv2D)       (None, 55, 55, 256)  16384       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2_1_1x1_increase/bn (BatchN (None, 55, 55, 256)  1024        conv2_1_1x1_increase[0][0]
# __________________________________________________________________________________________________
# conv2_1_1x1_proj/bn (BatchNorma (None, 55, 55, 256)  1024        conv2_1_1x1_proj[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 55, 55, 256)  0           conv2_1_1x1_increase/bn[0][0]
#                                                                  conv2_1_1x1_proj/bn[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 55, 55, 256)  0           add_33[0][0]
# __________________________________________________________________________________________________
# conv2_2_1x1_reduce (Conv2D)     (None, 55, 55, 64)   16384       activation_102[0][0]
# __________________________________________________________________________________________________
# conv2_2_1x1_reduce/bn (BatchNor (None, 55, 55, 64)   256         conv2_2_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 55, 55, 64)   0           conv2_2_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv2_2_3x3 (Conv2D)            (None, 55, 55, 64)   36864       activation_103[0][0]
# __________________________________________________________________________________________________
# conv2_2_3x3/bn (BatchNormalizat (None, 55, 55, 64)   256         conv2_2_3x3[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 55, 55, 64)   0           conv2_2_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv2_2_1x1_increase (Conv2D)   (None, 55, 55, 256)  16384       activation_104[0][0]
# __________________________________________________________________________________________________
# conv2_2_1x1_increase/bn (BatchN (None, 55, 55, 256)  1024        conv2_2_1x1_increase[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 55, 55, 256)  0           conv2_2_1x1_increase/bn[0][0]
#                                                                  activation_102[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 55, 55, 256)  0           add_34[0][0]
# __________________________________________________________________________________________________
# conv2_3_1x1_reduce (Conv2D)     (None, 55, 55, 64)   16384       activation_105[0][0]
# __________________________________________________________________________________________________
# conv2_3_1x1_reduce/bn (BatchNor (None, 55, 55, 64)   256         conv2_3_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 55, 55, 64)   0           conv2_3_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv2_3_3x3 (Conv2D)            (None, 55, 55, 64)   36864       activation_106[0][0]
# __________________________________________________________________________________________________
# conv2_3_3x3/bn (BatchNormalizat (None, 55, 55, 64)   256         conv2_3_3x3[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 55, 55, 64)   0           conv2_3_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv2_3_1x1_increase (Conv2D)   (None, 55, 55, 256)  16384       activation_107[0][0]
# __________________________________________________________________________________________________
# conv2_3_1x1_increase/bn (BatchN (None, 55, 55, 256)  1024        conv2_3_1x1_increase[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 55, 55, 256)  0           conv2_3_1x1_increase/bn[0][0]
#                                                                  activation_105[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 55, 55, 256)  0           add_35[0][0]
# __________________________________________________________________________________________________
# conv3_1_1x1_reduce (Conv2D)     (None, 28, 28, 128)  32768       activation_108[0][0]
# __________________________________________________________________________________________________
# conv3_1_1x1_reduce/bn (BatchNor (None, 28, 28, 128)  512         conv3_1_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 28, 28, 128)  0           conv3_1_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv3_1_3x3 (Conv2D)            (None, 28, 28, 128)  147456      activation_109[0][0]
# __________________________________________________________________________________________________
# conv3_1_3x3/bn (BatchNormalizat (None, 28, 28, 128)  512         conv3_1_3x3[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 28, 28, 128)  0           conv3_1_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv3_1_1x1_increase (Conv2D)   (None, 28, 28, 512)  65536       activation_110[0][0]
# __________________________________________________________________________________________________
# conv3_1_1x1_proj (Conv2D)       (None, 28, 28, 512)  131072      activation_108[0][0]
# __________________________________________________________________________________________________
# conv3_1_1x1_increase/bn (BatchN (None, 28, 28, 512)  2048        conv3_1_1x1_increase[0][0]
# __________________________________________________________________________________________________
# conv3_1_1x1_proj/bn (BatchNorma (None, 28, 28, 512)  2048        conv3_1_1x1_proj[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 28, 28, 512)  0           conv3_1_1x1_increase/bn[0][0]
#                                                                  conv3_1_1x1_proj/bn[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 28, 28, 512)  0           add_36[0][0]
# __________________________________________________________________________________________________
# conv3_2_1x1_reduce (Conv2D)     (None, 28, 28, 128)  65536       activation_111[0][0]
# __________________________________________________________________________________________________
# conv3_2_1x1_reduce/bn (BatchNor (None, 28, 28, 128)  512         conv3_2_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 28, 28, 128)  0           conv3_2_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv3_2_3x3 (Conv2D)            (None, 28, 28, 128)  147456      activation_112[0][0]
# __________________________________________________________________________________________________
# conv3_2_3x3/bn (BatchNormalizat (None, 28, 28, 128)  512         conv3_2_3x3[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 28, 28, 128)  0           conv3_2_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv3_2_1x1_increase (Conv2D)   (None, 28, 28, 512)  65536       activation_113[0][0]
# __________________________________________________________________________________________________
# conv3_2_1x1_increase/bn (BatchN (None, 28, 28, 512)  2048        conv3_2_1x1_increase[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 28, 28, 512)  0           conv3_2_1x1_increase/bn[0][0]
#                                                                  activation_111[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 28, 28, 512)  0           add_37[0][0]
# __________________________________________________________________________________________________
# conv3_3_1x1_reduce (Conv2D)     (None, 28, 28, 128)  65536       activation_114[0][0]
# __________________________________________________________________________________________________
# conv3_3_1x1_reduce/bn (BatchNor (None, 28, 28, 128)  512         conv3_3_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 28, 28, 128)  0           conv3_3_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv3_3_3x3 (Conv2D)            (None, 28, 28, 128)  147456      activation_115[0][0]
# __________________________________________________________________________________________________
# conv3_3_3x3/bn (BatchNormalizat (None, 28, 28, 128)  512         conv3_3_3x3[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 28, 28, 128)  0           conv3_3_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv3_3_1x1_increase (Conv2D)   (None, 28, 28, 512)  65536       activation_116[0][0]
# __________________________________________________________________________________________________
# conv3_3_1x1_increase/bn (BatchN (None, 28, 28, 512)  2048        conv3_3_1x1_increase[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 28, 28, 512)  0           conv3_3_1x1_increase/bn[0][0]
#                                                                  activation_114[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 28, 28, 512)  0           add_38[0][0]
# __________________________________________________________________________________________________
# conv3_4_1x1_reduce (Conv2D)     (None, 28, 28, 128)  65536       activation_117[0][0]
# __________________________________________________________________________________________________
# conv3_4_1x1_reduce/bn (BatchNor (None, 28, 28, 128)  512         conv3_4_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 28, 28, 128)  0           conv3_4_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv3_4_3x3 (Conv2D)            (None, 28, 28, 128)  147456      activation_118[0][0]
# __________________________________________________________________________________________________
# conv3_4_3x3/bn (BatchNormalizat (None, 28, 28, 128)  512         conv3_4_3x3[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 28, 28, 128)  0           conv3_4_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv3_4_1x1_increase (Conv2D)   (None, 28, 28, 512)  65536       activation_119[0][0]
# __________________________________________________________________________________________________
# conv3_4_1x1_increase/bn (BatchN (None, 28, 28, 512)  2048        conv3_4_1x1_increase[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 28, 28, 512)  0           conv3_4_1x1_increase/bn[0][0]
#                                                                  activation_117[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 28, 28, 512)  0           add_39[0][0]
# __________________________________________________________________________________________________
# conv4_1_1x1_reduce (Conv2D)     (None, 14, 14, 256)  131072      activation_120[0][0]
# __________________________________________________________________________________________________
# conv4_1_1x1_reduce/bn (BatchNor (None, 14, 14, 256)  1024        conv4_1_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 14, 14, 256)  0           conv4_1_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv4_1_3x3 (Conv2D)            (None, 14, 14, 256)  589824      activation_121[0][0]
# __________________________________________________________________________________________________
# conv4_1_3x3/bn (BatchNormalizat (None, 14, 14, 256)  1024        conv4_1_3x3[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 14, 14, 256)  0           conv4_1_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv4_1_1x1_increase (Conv2D)   (None, 14, 14, 1024) 262144      activation_122[0][0]
# __________________________________________________________________________________________________
# conv4_1_1x1_proj (Conv2D)       (None, 14, 14, 1024) 524288      activation_120[0][0]
# __________________________________________________________________________________________________
# conv4_1_1x1_increase/bn (BatchN (None, 14, 14, 1024) 4096        conv4_1_1x1_increase[0][0]
# __________________________________________________________________________________________________
# conv4_1_1x1_proj/bn (BatchNorma (None, 14, 14, 1024) 4096        conv4_1_1x1_proj[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 14, 14, 1024) 0           conv4_1_1x1_increase/bn[0][0]
#                                                                  conv4_1_1x1_proj/bn[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 14, 14, 1024) 0           add_40[0][0]
# __________________________________________________________________________________________________
# conv4_2_1x1_reduce (Conv2D)     (None, 14, 14, 256)  262144      activation_123[0][0]
# __________________________________________________________________________________________________
# conv4_2_1x1_reduce/bn (BatchNor (None, 14, 14, 256)  1024        conv4_2_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 14, 14, 256)  0           conv4_2_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv4_2_3x3 (Conv2D)            (None, 14, 14, 256)  589824      activation_124[0][0]
# __________________________________________________________________________________________________
# conv4_2_3x3/bn (BatchNormalizat (None, 14, 14, 256)  1024        conv4_2_3x3[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 14, 14, 256)  0           conv4_2_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv4_2_1x1_increase (Conv2D)   (None, 14, 14, 1024) 262144      activation_125[0][0]
# __________________________________________________________________________________________________
# conv4_2_1x1_increase/bn (BatchN (None, 14, 14, 1024) 4096        conv4_2_1x1_increase[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 14, 14, 1024) 0           conv4_2_1x1_increase/bn[0][0]
#                                                                  activation_123[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 14, 14, 1024) 0           add_41[0][0]
# __________________________________________________________________________________________________
# conv4_3_1x1_reduce (Conv2D)     (None, 14, 14, 256)  262144      activation_126[0][0]
# __________________________________________________________________________________________________
# conv4_3_1x1_reduce/bn (BatchNor (None, 14, 14, 256)  1024        conv4_3_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 14, 14, 256)  0           conv4_3_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv4_3_3x3 (Conv2D)            (None, 14, 14, 256)  589824      activation_127[0][0]
# __________________________________________________________________________________________________
# conv4_3_3x3/bn (BatchNormalizat (None, 14, 14, 256)  1024        conv4_3_3x3[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 14, 14, 256)  0           conv4_3_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv4_3_1x1_increase (Conv2D)   (None, 14, 14, 1024) 262144      activation_128[0][0]
# __________________________________________________________________________________________________
# conv4_3_1x1_increase/bn (BatchN (None, 14, 14, 1024) 4096        conv4_3_1x1_increase[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 14, 14, 1024) 0           conv4_3_1x1_increase/bn[0][0]
#                                                                  activation_126[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 14, 14, 1024) 0           add_42[0][0]
# __________________________________________________________________________________________________
# conv4_4_1x1_reduce (Conv2D)     (None, 14, 14, 256)  262144      activation_129[0][0]
# __________________________________________________________________________________________________
# conv4_4_1x1_reduce/bn (BatchNor (None, 14, 14, 256)  1024        conv4_4_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 14, 14, 256)  0           conv4_4_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv4_4_3x3 (Conv2D)            (None, 14, 14, 256)  589824      activation_130[0][0]
# __________________________________________________________________________________________________
# conv4_4_3x3/bn (BatchNormalizat (None, 14, 14, 256)  1024        conv4_4_3x3[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 14, 14, 256)  0           conv4_4_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv4_4_1x1_increase (Conv2D)   (None, 14, 14, 1024) 262144      activation_131[0][0]
# __________________________________________________________________________________________________
# conv4_4_1x1_increase/bn (BatchN (None, 14, 14, 1024) 4096        conv4_4_1x1_increase[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 14, 14, 1024) 0           conv4_4_1x1_increase/bn[0][0]
#                                                                  activation_129[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 14, 14, 1024) 0           add_43[0][0]
# __________________________________________________________________________________________________
# conv4_5_1x1_reduce (Conv2D)     (None, 14, 14, 256)  262144      activation_132[0][0]
# __________________________________________________________________________________________________
# conv4_5_1x1_reduce/bn (BatchNor (None, 14, 14, 256)  1024        conv4_5_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 14, 14, 256)  0           conv4_5_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv4_5_3x3 (Conv2D)            (None, 14, 14, 256)  589824      activation_133[0][0]
# __________________________________________________________________________________________________
# conv4_5_3x3/bn (BatchNormalizat (None, 14, 14, 256)  1024        conv4_5_3x3[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 14, 14, 256)  0           conv4_5_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv4_5_1x1_increase (Conv2D)   (None, 14, 14, 1024) 262144      activation_134[0][0]
# __________________________________________________________________________________________________
# conv4_5_1x1_increase/bn (BatchN (None, 14, 14, 1024) 4096        conv4_5_1x1_increase[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 14, 14, 1024) 0           conv4_5_1x1_increase/bn[0][0]
#                                                                  activation_132[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 14, 14, 1024) 0           add_44[0][0]
# __________________________________________________________________________________________________
# conv4_6_1x1_reduce (Conv2D)     (None, 14, 14, 256)  262144      activation_135[0][0]
# __________________________________________________________________________________________________
# conv4_6_1x1_reduce/bn (BatchNor (None, 14, 14, 256)  1024        conv4_6_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 14, 14, 256)  0           conv4_6_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv4_6_3x3 (Conv2D)            (None, 14, 14, 256)  589824      activation_136[0][0]
# __________________________________________________________________________________________________
# conv4_6_3x3/bn (BatchNormalizat (None, 14, 14, 256)  1024        conv4_6_3x3[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 14, 14, 256)  0           conv4_6_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv4_6_1x1_increase (Conv2D)   (None, 14, 14, 1024) 262144      activation_137[0][0]
# __________________________________________________________________________________________________
# conv4_6_1x1_increase/bn (BatchN (None, 14, 14, 1024) 4096        conv4_6_1x1_increase[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 14, 14, 1024) 0           conv4_6_1x1_increase/bn[0][0]
#                                                                  activation_135[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 14, 14, 1024) 0           add_45[0][0]
# __________________________________________________________________________________________________
# conv5_1_1x1_reduce (Conv2D)     (None, 7, 7, 512)    524288      activation_138[0][0]
# __________________________________________________________________________________________________
# conv5_1_1x1_reduce/bn (BatchNor (None, 7, 7, 512)    2048        conv5_1_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 7, 7, 512)    0           conv5_1_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv5_1_3x3 (Conv2D)            (None, 7, 7, 512)    2359296     activation_139[0][0]
# __________________________________________________________________________________________________
# conv5_1_3x3/bn (BatchNormalizat (None, 7, 7, 512)    2048        conv5_1_3x3[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 7, 7, 512)    0           conv5_1_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv5_1_1x1_increase (Conv2D)   (None, 7, 7, 2048)   1048576     activation_140[0][0]
# __________________________________________________________________________________________________
# conv5_1_1x1_proj (Conv2D)       (None, 7, 7, 2048)   2097152     activation_138[0][0]
# __________________________________________________________________________________________________
# conv5_1_1x1_increase/bn (BatchN (None, 7, 7, 2048)   8192        conv5_1_1x1_increase[0][0]
# __________________________________________________________________________________________________
# conv5_1_1x1_proj/bn (BatchNorma (None, 7, 7, 2048)   8192        conv5_1_1x1_proj[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 7, 7, 2048)   0           conv5_1_1x1_increase/bn[0][0]
#                                                                  conv5_1_1x1_proj/bn[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 7, 7, 2048)   0           add_46[0][0]
# __________________________________________________________________________________________________
# conv5_2_1x1_reduce (Conv2D)     (None, 7, 7, 512)    1048576     activation_141[0][0]
# __________________________________________________________________________________________________
# conv5_2_1x1_reduce/bn (BatchNor (None, 7, 7, 512)    2048        conv5_2_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 7, 7, 512)    0           conv5_2_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv5_2_3x3 (Conv2D)            (None, 7, 7, 512)    2359296     activation_142[0][0]
# __________________________________________________________________________________________________
# conv5_2_3x3/bn (BatchNormalizat (None, 7, 7, 512)    2048        conv5_2_3x3[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 7, 7, 512)    0           conv5_2_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv5_2_1x1_increase (Conv2D)   (None, 7, 7, 2048)   1048576     activation_143[0][0]
# __________________________________________________________________________________________________
# conv5_2_1x1_increase/bn (BatchN (None, 7, 7, 2048)   8192        conv5_2_1x1_increase[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 7, 7, 2048)   0           conv5_2_1x1_increase/bn[0][0]
#                                                                  activation_141[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 7, 7, 2048)   0           add_47[0][0]
# __________________________________________________________________________________________________
# conv5_3_1x1_reduce (Conv2D)     (None, 7, 7, 512)    1048576     activation_144[0][0]
# __________________________________________________________________________________________________
# conv5_3_1x1_reduce/bn (BatchNor (None, 7, 7, 512)    2048        conv5_3_1x1_reduce[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 7, 7, 512)    0           conv5_3_1x1_reduce/bn[0][0]
# __________________________________________________________________________________________________
# conv5_3_3x3 (Conv2D)            (None, 7, 7, 512)    2359296     activation_145[0][0]
# __________________________________________________________________________________________________
# conv5_3_3x3/bn (BatchNormalizat (None, 7, 7, 512)    2048        conv5_3_3x3[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 7, 7, 512)    0           conv5_3_3x3/bn[0][0]
# __________________________________________________________________________________________________
# conv5_3_1x1_increase (Conv2D)   (None, 7, 7, 2048)   1048576     activation_146[0][0]
# __________________________________________________________________________________________________
# conv5_3_1x1_increase/bn (BatchN (None, 7, 7, 2048)   8192        conv5_3_1x1_increase[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 7, 7, 2048)   0           conv5_3_1x1_increase/bn[0][0]
#                                                                  activation_144[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 7, 7, 2048)   0           add_48[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_147[0][0]
# ==================================================================================================
# Total params: 23,561,152
# Trainable params: 23,508,032
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Len layers:  174
# [INFO] evaluating after fine-tuning network head...
# <keras.engine.input_layer.InputLayer object at 0x7fc8e8160d30>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e81603c8>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e81604e0>: True
# <keras.layers.core.Activation object at 0x7fc8e8160da0>: True
# <keras.layers.pooling.MaxPooling2D object at 0x7fc8e8160f28>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e8a674a8>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e8a08358>: True
# <keras.layers.core.Activation object at 0x7fc8e8a08da0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e8a08ef0>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e8a3dcc0>: True
# <keras.layers.core.Activation object at 0x7fc8e89c3f98>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e89c99b0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e89825f8>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e8982668>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e8941e10>: True
# <keras.layers.merge.Add object at 0x7fc8e8941eb8>: True
# <keras.layers.core.Activation object at 0x7fc8e895cf98>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e8979630>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e8908f28>: True
# <keras.layers.core.Activation object at 0x7fc8e8910c88>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e8910ef0>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e88c7fd0>: True
# <keras.layers.core.Activation object at 0x7fc8e88cd668>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e88d7c50>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e888c908>: True
# <keras.layers.merge.Add object at 0x7fc8e888c898>: True
# <keras.layers.core.Activation object at 0x7fc8e88a2ac8>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e88b7518>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e8854cf8>: True
# <keras.layers.core.Activation object at 0x7fc8e8854ef0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e885efd0>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e8815c18>: True
# <keras.layers.core.Activation object at 0x7fc8e881aef0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e8824470>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e87da5c0>: True
# <keras.layers.merge.Add object at 0x7fc8e87da550>: True
# <keras.layers.core.Activation object at 0x7fc8e87f5e48>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e87efe48>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e87a29b0>: True
# <keras.layers.core.Activation object at 0x7fc8e87a2f98>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e87a8cc0>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e8763978>: True
# <keras.layers.core.Activation object at 0x7fc8e8763908>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc8e8768e80>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d469898>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d469278>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d427a20>: True
# <keras.layers.merge.Add object at 0x7fc72d427ac8>: True
# <keras.layers.core.Activation object at 0x7fc72d3c6fd0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d3e6f28>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d3f0c50>: True
# <keras.layers.core.Activation object at 0x7fc72d3f0fd0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d3f8f60>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d3afba8>: True
# <keras.layers.core.Activation object at 0x7fc72d3b7f98>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d3b7fd0>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d375550>: True
# <keras.layers.merge.Add object at 0x7fc72d3754e0>: True
# <keras.layers.core.Activation object at 0x7fc72d30ba90>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d30bc18>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d33d940>: True
# <keras.layers.core.Activation object at 0x7fc72d33df28>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d2c5c50>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d2fc908>: True
# <keras.layers.core.Activation object at 0x7fc72d2fc898>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d283e10>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d2b8208>: True
# <keras.layers.merge.Add object at 0x7fc72d2b8828>: True
# <keras.layers.core.Activation object at 0x7fc72d257748>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d257fd0>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d20a5f8>: True
# <keras.layers.core.Activation object at 0x7fc72d20aef0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d215470>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d1ca5c0>: True
# <keras.layers.core.Activation object at 0x7fc72d1ca550>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d1d5eb8>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d18add8>: True
# <keras.layers.merge.Add object at 0x7fc72d193fd0>: True
# <keras.layers.core.Activation object at 0x7fc72d1a6cf8>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d1aee10>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d153e10>: True
# <keras.layers.core.Activation object at 0x7fc72d15ae10>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d15ae48>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d119240>: True
# <keras.layers.core.Activation object at 0x7fc72d119860>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d122e48>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d0dfd68>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d0d7a90>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d0a19e8>: True
# <keras.layers.merge.Add object at 0x7fc72d0a1a90>: True
# <keras.layers.core.Activation object at 0x7fc72d0bcfd0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d0595c0>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d066e48>: True
# <keras.layers.core.Activation object at 0x7fc72d06ef60>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d06ef98>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72d02c390>: True
# <keras.layers.core.Activation object at 0x7fc72d02c9b0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72d037f60>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72cfebba8>: True
# <keras.layers.merge.Add object at 0x7fc72cff1f98>: True
# <keras.layers.core.Activation object at 0x7fc72cf87fd0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72cf8dbe0>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc72cf96e10>: True
# <keras.layers.core.Activation object at 0x7fc904dc6e48>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc904dc6e80>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc906bd8358>: True
# <keras.layers.core.Activation object at 0x7fc906bd8978>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc906bd5da0>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc906b9dba8>: True
# <keras.layers.merge.Add object at 0x7fc906bb1f98>: True
# <keras.layers.core.Activation object at 0x7fc907105fd0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc90711bc18>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc906c8d860>: True
# <keras.layers.core.Activation object at 0x7fc906c8dfd0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc906cb7b70>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc9050f4908>: True
# <keras.layers.core.Activation object at 0x7fc9050f4898>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc9050fadd8>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc9600972e8>: True
# <keras.layers.merge.Add object at 0x7fc9600978d0>: True
# <keras.layers.core.Activation object at 0x7fc90714e828>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc90714ee80>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc90706eeb8>: True
# <keras.layers.core.Activation object at 0x7fc907071d30>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc907071eb8>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc9071a7eb8>: True
# <keras.layers.core.Activation object at 0x7fc9071c2fd0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc9071b6ba8>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc8e81b3940>: True
# <keras.layers.merge.Add object at 0x7fc8e81b38d0>: True
# <keras.layers.core.Activation object at 0x7fc90668db00>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc9066a5908>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc905026e80>: True
# <keras.layers.core.Activation object at 0x7fc905033e48>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc905033f60>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc9050b65f8>: True
# <keras.layers.core.Activation object at 0x7fc9050b6588>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc9050beef0>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc96fffcef0>: True
# <keras.layers.merge.Add object at 0x7fc96fffe5f8>: True
# <keras.layers.core.Activation object at 0x7fc906c45e80>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc906c59f98>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc906611ba8>: True
# <keras.layers.core.Activation object at 0x7fc906611eb8>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc906621eb8>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc907040ba8>: True
# <keras.layers.core.Activation object at 0x7fc72cf9ef98>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc72cf9efd0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc9065b45c0>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc9065b4630>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc9067dc5f8>: True
# <keras.layers.merge.Add object at 0x7fc9067dce48>: True
# <keras.layers.core.Activation object at 0x7fc906801978>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc906801fd0>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc906786fd0>: True
# <keras.layers.core.Activation object at 0x7fc906791c18>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc906791e80>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc9066e1128>: True
# <keras.layers.core.Activation object at 0x7fc9066e1748>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc9066f1d30>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc90667da20>: True
# <keras.layers.merge.Add object at 0x7fc90667df98>: True
# <keras.layers.core.Activation object at 0x7fc90685cfd0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc90686aa90>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc9068a36d8>: True
# <keras.layers.core.Activation object at 0x7fc9068a3fd0>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc9068ae9e8>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc906f97780>: True
# <keras.layers.core.Activation object at 0x7fc906f97710>: True
# <keras.layers.convolutional.Conv2D object at 0x7fc906fbaef0>: True
# <keras.layers.normalization.BatchNormalization object at 0x7fc906edb198>: True
# <keras.layers.merge.Add object at 0x7fc906edb780>: True
# <keras.layers.core.Activation object at 0x7fc906ec66a0>: True
# <keras.layers.pooling.AveragePooling2D object at 0x7fc906ec6f98>: True
# [INFO] re-compiling model...
# Epoch 1/15
#  906/4673 [====>.........................] - ETA: 36:18 - loss: 0.5067 - acc: 0.74690
# 2531/4673 [===============>..............] - ETA: 20:20 - loss: 0.3776 - acc: 0.82201
# 2636/4673 [===============>..............] - ETA: 19:19 - loss: 0.3720 - acc: 0.82492
# 4673/4673 [==============================] - 2737s 586ms/step - loss: 0.3019 - acc: 0.8622 - val_loss: 0.2538 - val_acc: 0.8920
#
# Epoch 00001: val_loss improved from inf to 0.25380, saving model to drive/My Drive/VGGFace_ResNet50_custommodel/weights.01-0.25.hdf5
# Epoch 2/15
# 1795/4673 [==========>...................] - ETA: 26:47 - loss: 0.1553 - acc: 0.93383
# 3635/4673 [======================>.......] - ETA: 9:51 - loss: 0.1481 - acc: 0.93654
# 3842/4673 [=======================>......] - ETA: 7:54 - loss: 0.1476 - acc: 0.93675
# 4673/4673 [==============================] - 2766s 592ms/step - loss: 0.1450 - acc: 0.9377 - val_loss: 0.1230 - val_acc: 0.9468
#
# Epoch 00002: val_loss improved from 0.25380 to 0.12303, saving model to drive/My Drive/VGGFace_ResNet50_custommodel/weights.02-0.12.hdf5
# Epoch 3/15
# 2023/4673 [===========>..................] - ETA: 24:27 - loss: 0.1100 - acc: 0.9526
